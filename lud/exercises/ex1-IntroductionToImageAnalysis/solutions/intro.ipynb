# %%
import os
import matplotlib
matplotlib.use("TkAgg")
import matplotlib.pyplot as plt
import pydicom as dicom
import numpy as np
from skimage import color, io, measure
from skimage.util import img_as_ubyte
from skimage.measure import profile_line
from skimage.transform import rescale, resize

# %%
# Directory containing data and images
in_dir = "../data/"
cwd = os.getcwd()
# X-ray image
im_name = "metacarpals.png"

# Read the image.
# Here the directory and the image name is concatenated
# by "+" to give the full path to the image.
im_org = io.imread(in_dir + im_name)

print(f"Image shape: { im_org.shape }, image pixel type: {im_org.dtype}")

# Display image
io.imshow(im_org)
plt.title('Metacarpal image')
plt.savefig(cwd+'/metacarpal.png')

# Display image with colormap
io.imshow(im_org, cmap="jet") # Examples of other color maps: cool, hot, pink, copper
plt.title('Metacarpal image')
plt.savefig(cwd+'/metacarpal_colormap.png')
# Second try with cool cmap
io.imshow(im_org, cmap="cool")
plt.title('Metacarpal image (cool)')
plt.savefig(cwd+'/metacarpal_cool.png')

# Grayscale image
io.imshow(im_org, vmin=20, vmax=170) # Here, we enhance contrast by setting all pixels to 0 with p_x<=20, and those to 255 that have p_x>=170
plt.title('Metacarpal image (with gray level scaling)')
plt.savefig(cwd+'/metacarpal_scale.png')
# Out:
# Image shape: (512, 512), image pixel type: uint8
# /tmp/ipykernel_142231/942983270.py:15: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(im_org)
# /tmp/ipykernel_142231/942983270.py:20: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(im_org, cmap="jet") # Examples of other color maps: cool, hot, pink, copper
# /tmp/ipykernel_142231/942983270.py:24: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(im_org, cmap="cool")
# /tmp/ipykernel_142231/942983270.py:29: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
# ...

# %% [markdown]
# #### Histograms

# %%
plt.hist(im_org.ravel(), bins=256)
plt.title('Image histogram')
io.show()

# How plt.hist works:
h = plt.hist(im_org.ravel(), bins = 256)
# h is a list of tuples, where the first element h[0][i] for each tuple is the COUNT within bin i and h[1][i] is the BIN_EDGE

# Bin edges for bin i can then be found as follows:
i = 40
i_count = h[0][i]
left_edge = h[1][i]
right_edge = h[1][i+1]
print(f"Left edge: {left_edge}, right_edge: {right_edge}")

# Alternative way of calling hist:
count, x, _ = plt.hist(im_org.ravel(), bins=256)

# TODO 9: find most common range of intensities
common_bin = np.argmax(h[0][:])
print(f"Most common bin: {common_bin}, with value: {h[0][common_bin]}")
# Out:
# /tmp/ipykernel_38107/1362618422.py:3: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
# Left edge: 59.5, right_edge: 60.1875
# Most common bin: 117, with value: 5848.0

# %% [markdown]
# #### Pixel values

# %%
im_org = io.imread(in_dir + im_name)
#TODO 10: pixel value at (r,c)=(110, 90)
p = im_org[110,90]
print(f"Pixel value at (110, 90): {p}")

#TODO 11: what does this operation do? (on slicing)
im_org[:30] = 0
io.imshow(im_org)
io.show()
    # Slices the image such, that all rows up to row 30 retrieve value == 0

# TODO 12: where are the values 1 and where are they 0 for the following masking?:
mask = im_org > 150
io.imshow(mask)
io.show()
    # Only pixels with values > 150 have 1, else 0

# TODO 13: What does this code do?:
im_org[mask] = 255
io.imshow(im_org)
io.show()
    # Resets the mask to uint format, having range (0,255), where pixels with value 255 previously had value 1
# Out:
# Pixel value at (110, 90): 120
# /tmp/ipykernel_38107/1991471254.py:8: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(im_org)
# /tmp/ipykernel_38107/1991471254.py:9: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
# /tmp/ipykernel_38107/1991471254.py:14: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(mask)
# /tmp/ipykernel_38107/1991471254.py:15: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
# ...

# %% [markdown]
# #### Color images

# %%
# TODO 14: read and print image dims, pixel type of image: ardeche.jpg:
rgb_img = io.imread(in_dir + 'ardeche.jpg')
print(f'RGB image shape: {rgb_img.shape}, dtype: {rgb_img.dtype}')

# TODO 15: RGB values at (110,90)?:
print(f'Values at position (110,90): {rgb_img[110, 90, :]}')

# TODO 16: color upper half of photo green:
rgb_img[:int( rgb_img.shape[0]/2 ), :, 0] = 0
rgb_img[:int( rgb_img.shape[0]/2 ), :, 1] = 255
rgb_img[:int( rgb_img.shape[0]/2 ), :, 2] = 0
io.imshow(rgb_img)
io.show()
# Out:
# RGB image shape: (600, 800, 3), dtype: uint8
# Values at position (110,90): [119 178 238]
# /tmp/ipykernel_38107/2513812748.py:12: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(rgb_img)
# /tmp/ipykernel_38107/2513812748.py:13: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# #### Working with your own image

# %% [markdown]
# **Exercise 17**: read own image

# %%
path_to_img = "/home/ludvikpet/.config/backgrounds/lofiwallpaper.png"
my_img = io.imread(path_to_img)
io.imshow(my_img)
io.show()

# Size of image
print(f"Shape: {my_img.shape}, dtype: {my_img.dtype}")
# Out:
# /tmp/ipykernel_111458/3895576339.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(my_img)
# /tmp/ipykernel_111458/3895576339.py:4: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
# Shape: (1076, 1920, 3), dtype: uint8

# %% [markdown]
# **Exercise 18**: What is the type of pixels after rescaling?

# %%
# Rescale image for ease
image_rescaled = rescale(my_img, 0.25, anti_aliasing=True, channel_axis=2)
    # What we specify: scale factor = 0.25; we have more than 1 channel (RGB); and channels are found at the third dim (2)

# Show image
io.imshow(image_rescaled)
io.show()

# Image attributes
print(f"Shape: {image_rescaled.shape}, dtype: {image_rescaled.dtype}") # dtype changed from uint8 to float64 (makes sense)
# Out:
# /tmp/ipykernel_87753/2235410407.py:6: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(image_rescaled)
# /tmp/ipykernel_87753/2235410407.py:7: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
# Shape: (270, 480, 3), dtype: float64

# %% [markdown]
# **Exercise 19**: Automatically scale image such, that width = 400 no matter of image size

# %%
h,w,c =my_img.shape
factor = 400 / w
img_auto_scaled = rescale(my_img, factor, anti_aliasing=True, channel_axis=2)

print(f"Shape: {img_auto_scaled.shape}, dtype: {image_rescaled.dtype}")
# Out:
# Shape: (225, 400, 3), dtype: float64

# %% [markdown]
# **Exercise 19.2**: Compute and show the hist of your own image, but grayscaled

# %%
# Convert image to grayscale
im_gray = color.rgb2gray(my_img)
im_byte = img_as_ubyte(im_gray) # Force image to have type ubyte (rgb2gray returns float)
# Compute hist
h = plt.hist(im_byte.ravel(), bins=256)
io.show()
# Out:
# /tmp/ipykernel_87753/3416167072.py:4: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(im_byte)
# /tmp/ipykernel_87753/3416167072.py:5: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
# /tmp/ipykernel_87753/3416167072.py:8: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# **Exercise 20**: Take dark and light image - compute and viz hists of the two images. Explain difference between images.

# %%
plt.hist(my_img.ravel(), bins=256)
io.show()
# Out:
# /tmp/ipykernel_111458/3432556883.py:2: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
# Read dark image
dark_image_path = "~/Desktop/Life/me.jpg"
dark_img = io.imread(dark_image_path)

plt.hist(my_img.ravel(), bins=256)
plt.hist(dark_img.ravel(), bins=256)
io.show()
# Out:
# /tmp/ipykernel_111458/209776129.py:7: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# Dark image is a lot more represented within lower pixel range (0-100), opposite for light image

# %% [markdown]
# **Exercise 21**: Retrieve image with dark bg and object - recognize the object using tools reviewed so far

# %%
gj_img = io.imread('~/Downloads/green_jacket.jpeg')


plt.hist(img_as_ubyte(color.rgb2gray(gj_img)).ravel(), bins=256)
io.show()
# Out:
# /tmp/ipykernel_111458/1455284491.py:5: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %% [markdown]
# **Exercise 22**: Read and show sign image

# %%
sign_img = io.imread(in_dir+"DTUSign1.jpg")
io.imshow(sign_img)
io.show()
print(f"Shape: {sign_img.shape}, type: {sign_img.dtype}")
# Out:
# /tmp/ipykernel_142231/3161591381.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(sign_img)
# /tmp/ipykernel_142231/3161591381.py:3: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
# invalid command name "138362452969472partial"
#     while executing
# "138362452969472partial"
#     ("after" script)
# Shape: (3024, 4032, 3), type: uint8

# %% [markdown]
# **Exercise 23**: Visualize R, G and B components individually

# %%
fig, ax = plt.subplots(3,1, figsize=(13,5))
for i in range(3):
    ax[i].imshow(sign_img[:,:,i], cmap='gray')

io.show()
# Out:
# /tmp/ipykernel_142231/4109697806.py:5: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
